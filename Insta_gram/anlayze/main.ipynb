# %%
from kiwi_module import KiwiNounExtractor, KiwiNounAdjectiveExtractor, save_df_to_csv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from kiwi_module import KiwiNounExtractor, KiwiNounAdjectiveExtractor, save_df_to_csv
#
# ImportError: cannot import name 'KiwiNounAdjectiveExtractor' from 'kiwi_module' (/home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/kiwi_module.py)

# %%
# 명사추출 후 저장하는 코드
extractor = KiwiNounExtractor()
df = extractor.extract_nouns_from_csv("/home/kang/PythonProject/Project 1./Text_Project/DATA/instagram_comments_korean_cleaned.csv")

# %%
# 저장
save_df_to_csv(
    df,
    "/home/kang/PythonProject/Project 1./Text_Project/Insta_gram/DATA/with_nouns.csv"
)
# Out:
# ✅ 저장 완료: /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/DATA/with_nouns.csv

# %%
# 워드클라우드 그리기
from cloud import WordCloudGenerator

# %%
cloud = WordCloudGenerator("/home/kang/PythonProject/Project 1./Text_Project/Insta_gram/DATA/with_nouns.csv")

# %%
cloud.show_wordcloud("이재명")
# Out:
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51116 (\N{HANGUL SYLLABLE JAE}) missing from font(s) DejaVu Sans.
# ...

# %%
cloud.show_wordcloud("김문수")
# Out:
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 44608 (\N{HANGUL SYLLABLE GIM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47928 (\N{HANGUL SYLLABLE MUN}) missing from font(s) DejaVu Sans.
# ...

# %%
cloud.show_wordcloud("이준석")
# Out:
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/PythonProject/Project 1./Text_Project/Insta_gram/anlayze/cloud.py:57: UserWarning: Glyph 49437 (\N{HANGUL SYLLABLE SEOG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/kang/anaconda3/envs/txt/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51456 (\N{HANGUL SYLLABLE JUN}) missing from font(s) DejaVu Sans.
# ...

# %%
# 명사추출 후 저장하는 코드
extractor2 = KiwiNounAdjectiveExtractor()
df = extractor.extract_nouns_from_csv("/home/kang/PythonProject/Project 1./Text_Project/DATA/instagram_comments_korean_cleaned.csv")
